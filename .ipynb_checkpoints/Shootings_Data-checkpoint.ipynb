# %%
import pandas as pd
import requests

# %%
shootings_df = pd.read_csv("Stanford_MSA_Shooting.csv")
shootings_df.head()
# Out:
#    CaseID                           Title                Location  \
# 0       1   University of Texas at Austin           Austin, Texas
# 1       2      Rose-Mar College of Beauty           Mesa, Arizona
# 2       3    New Orleans Police Shootings  New Orleans, Louisiana
# 3       4  Clara Barton Elementary School       Chicago, Illinois
# 4       5               Olean High School         Olean, New York
#
#           City      State   Latitude   Longitude  \
# 0       Austin      Texas  30.198887  -97.844159
# 1         Mesa    Arizona  33.422687 -111.816320
# 2  New Orleans  Louisiana  30.068724  -89.931474
# 3      Chicago   Illinois  41.839280  -87.688181
# 4        Olean   New York  42.081854  -78.432139
#
#    Number of Civilian Fatalities  Number of Civilian Injured  \
# 0                             15                          32
# 1                              5                           1
# 2                              4                           8
# ...

# %%
shootings_df = shootings_df.drop(columns=["Location", "Description", "Day of Week", 
                           "Date - Detailed", "Shooter Name", "Shooter Age(s)", "Shooter Name", "Average Shooter Age",
                           "Shooter Sex", "Shooter Race", "Type of Gun - Detailed", "Fate of Shooter at the scene",
                          "Fate of Shooter", "Shooter's Cause of Death", "School Related", "Place Type", "Targeted Victim/s - Detailed",
                          "Targeted Victim/s - General", "Possible Motive - Detailed", "Possible Motive - General",
                          "History of Mental Illness - Detailed", "History of Mental Illness - General", 
                          "Data Source 1", "Data Source 2", "Data Source 3", "Data Source 4", "Data Source 5", "Data Source 6",
                                         "Data Source 7", "Military Experience", "Class", "Depreciation", "Notes", "Edit Date"])
shootings_df.head()
# Out:
#    CaseID                           Title         City      State   Latitude  \
# 0       1   University of Texas at Austin       Austin      Texas  30.198887
# 1       2      Rose-Mar College of Beauty         Mesa    Arizona  33.422687
# 2       3    New Orleans Police Shootings  New Orleans  Louisiana  30.068724
# 3       4  Clara Barton Elementary School      Chicago   Illinois  41.839280
# 4       5               Olean High School        Olean   New York  42.081854
#
#     Longitude  Number of Civilian Fatalities  Number of Civilian Injured  \
# 0  -97.844159                             15                          32
# 1 -111.816320                              5                           1
# 2  -89.931474                              4                           8
# 3  -87.688181                              1                           3
# 4  -78.432139                              3                           7
#
# ...
